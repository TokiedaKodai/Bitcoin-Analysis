# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir_data = '../../Data/CryptoData/'
file_train = dir_data + 'train.csv'
file_hash = dir_data + 'HashRate.csv'
file_elect = dir_data + 'Electricity.csv'
file_trend = dir_data + 'Trend.csv'
file_spx = dir_data + 'SPXUSD.csv'

# %%
df_train = pd.read_csv(file_train)

# %%
df_train.head()
# Out:
#                   Date  ETHUSD_Volume  ZECUSD_Volume  LTCUSD_Volume  \
# 0  2019-03-19 00:00:00       2.506756            0.0        0.00000
# 1  2019-03-19 00:01:00       4.146010            0.0        0.00000
# 2  2019-03-19 00:02:00      10.000000            0.0        0.49999
# 3  2019-03-19 00:03:00       0.000000            0.0       33.62118
# 4  2019-03-19 00:04:00       0.000000            0.0       11.01871
#
#    BTCUSD_Volume  ETHUSD_Open_log  ETHUSD_High_log  ETHUSD_Low_log  \
# 0       0.000000         4.921294         4.921294        4.920492
# 1       0.000000         4.920492         4.920492        4.919251
# 2       0.000000         4.919251         4.919251        4.918885
# 3       0.030867         4.918885         4.918885        4.918885
# 4       2.286674         4.918885         4.918885        4.918885
#
#    ETHUSD_Close_log  ZECUSD_Open_log  ...  ZECUSD_Low_log  ZECUSD_Close_log  \
# ...

# %%
list_coin_name = ['BTC', 'ETH', 'LTC', 'ZEC']

# %%
for coin in list_coin_name:
    globals()[coin] = df_train[['Date', '%sUSD_Volume'%coin, '%sUSD_Close_log'%coin]]
    globals()[coin].columns = [['date', 'volume', 'close']]

# %%
BTC
# Out:
#                        date     volume      close
# 0       2019-03-19 00:00:00   0.000000   8.283757
# 1       2019-03-19 00:01:00   0.000000   8.283757
# 2       2019-03-19 00:02:00   0.000000   8.283757
# 3       2019-03-19 00:03:00   0.030867   8.284350
# 4       2019-03-19 00:04:00   2.286674   8.283759
# ...                     ...        ...        ...
# 986791  2021-03-18 23:55:00   0.042762  10.973400
# 986792  2021-03-18 23:56:00   0.493466  10.974290
# 986793  2021-03-18 23:57:00   0.291972  10.973915
# 986794  2021-03-18 23:58:00  16.107329  10.972547
# 986795  2021-03-18 23:59:00   1.241717  10.972369
#
# [986796 rows x 3 columns]

# %%
list_coin = [BTC, ETH, LTC, ZEC]

# %%
for df in list_coin:
    df[['date', 'close']].plot(subplots=False, figsize=(15, 5))

# %%
df_hash = pd.read_csv(file_hash)

# %%
df_hash.plot(subplots=False, figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
df_trend = pd.read_csv(file_trend)

# %%
df_trend.plot(subplots=False, figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
df_elect = pd.read_csv(file_elect)

# %%
df_elect.plot(subplots=False, figsize=(15, 5))
# Out:
# <AxesSubplot:>
