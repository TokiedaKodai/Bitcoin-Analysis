# %%
import pandas as pd
from pandas import Series, DataFrame
import json
from janome.tokenizer import Tokenizer
from requests_oauthlib import OAuth1Session
from wordcloud import WordCloud
import emoji
import re
import csv

# %%
def create_oauth_session(oauth_key_dict):
    oauth = OAuth1Session(
        oauth_key_dict['consumer_key'],
        oauth_key_dict['consumer_secret'],
        oauth_key_dict['access_token'],
        oauth_key_dict['access_token_secret']
    )
    return oauth

def search_tweet(word, count, oauth):
    url = 'https://api.twitter.com/1.1/search/tweets.json'
    params = {
        'q': word,
        'count' : count,
        'result_type' : 'recent',
        'exclude': 'retweets',
        'lang' : 'ja'
        }
    responce = oauth.get(url, params=params)
    if responce.status_code != 200:
        print("Error code: %d" %(responce.status_code))
        return None
    tweets = json.loads(responce.text)
    return tweets

def search_tweet_date(word, count, date, oauth):
    url = 'https://api.twitter.com/1.1/search/tweets.json'
    params = {
        'q': word,
        'count' : count,
        'result_type' : 'recent',
        'until' : date,
        'exclude': 'retweets',
        'lang' : 'ja'
        }
    responce = oauth.get(url, params=params)
    if responce.status_code != 200:
        print("Error code: %d" %(responce.status_code))
        return None
    tweets = json.loads(responce.text)
    return tweets

# %%
def remove_emoji(text):
    return ''.join(c for c in text if c not in emoji.UNICODE_EMOJI['en'])

def remove_url(text):
    return re.sub(r'https?://[\w/:%#\$&\?\(\)~\.=\+\-]+', '', text)
# Get Wakachigaki
def get_wakachi(list_text, word, hinshi=['名詞', '形容詞']):
    remove_words = ['こと', 'よう', 'そう', 'これ', 'それ', 'もの', 'ここ', 'さん', 'ちゃん',
                'ところ', 'とこ', 'の', 'ん', word]
    t = Tokenizer()
    wakachi = ''
    for text in list_text:
        malist = t.tokenize(text)
        for w in malist:
            word = w.surface
            part = w.part_of_speech
            hit = False
            for h in hinshi:
                hit = hit or (h in part)
            if not hit:
                continue
            if word not in remove_words:
                wakachi += word + ' '
    return wakachi

# %%
# Tweet Normalization
def normalize_tweets(tweets):
    normalized = []
    for tweet in tweets:
        text = tweet
        text = remove_emoji(text)
        text = remove_url(text)
        normalized.append(text)
    return normalized

# %%
keysfile = '../../twitter_API/key/keys.json'
keys = json.load(open(keysfile))
twitter = create_oauth_session(keys)

# %%
search_word = 'ビットコイン'
search_count = 10
date = '2021-04-30'

search = search_tweet_date(search_word, search_count, date, twitter)

# %%
search
# Out:
# {'statuses': [{'created_at': 'Thu Apr 29 23:59:53 +0000 2021',
#    'id': 1387919599698530304,
#    'id_str': '1387919599698530304',
#    'text': 'ビットコインは超長期視点で何も問題ないが、アメリカのFRBがテーパリングやるとアルトコインバブルは崩壊が近付いてきます。\n\n10年国債利回りは2017年と結構シンクロしています。\n\n今は17年でいうチャイナショックからの大回復局面… https://t.co/bHYqflCb7O',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bHYqflCb7O',
#       'expanded_url': 'https://twitter.com/i/web/status/1387919599698530304',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3322299168,
#     'id_str': '3322299168',
#     'name': '黒魔道士見習い',
#     'screen_name': 'bitcoinmoney888',
#     'location': '',
#     'description': '#bitcoin 1.4btc hodl',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4548,
#     'friends_count': 40,
#     'listed_count': 80,
#     'created_at': 'Fri Aug 21 12:48:43 +0000 2015',
#     'favourites_count': 30856,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 541,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1344285330120167426/KBeN_LZR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1344285330120167426/KBeN_LZR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3322299168/1618486408',
#     'profile_link_color': 'FFCC4D',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:59:53 +0000 2021',
#    'id': 1387919598226391041,
#    'id_str': '1387919598226391041',
#    'text': 'ビットコイン価格がバブル期に近づいてきている！ここからが楽しみですね〜。',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">cpkgseiu134</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1283321962106945537,
#     'id_str': '1283321962106945537',
#     'name': '体力派ネットビジネスレディ：ひな',
#     'screen_name': 'cpkgseiu134',
#     'location': '',
#     'description': 'アラサー、バツイチ、シングルマザーの”ひな”と申します。OLしながら、副業でネットビジネスやっています。頭には自信はないが体は人一倍丈夫なので、体力派ビジネスウーマンを目標に私に合ったビジネスを探し、難しくないことを繰り返して実行すれば成果が出るノウハウにのめり込んでいます。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 251,
#     'friends_count': 307,
#     'listed_count': 0,
#     'created_at': 'Wed Jul 15 08:46:27 +0000 2020',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 286,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1283322138947198976/FMNh4au2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283322138947198976/FMNh4au2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1283321962106945537/1617586877',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:59:50 +0000 2021',
#    'id': 1387919586285084674,
#    'id_str': '1387919586285084674',
#    'text': '【原油】\n期待したいですね～😆\n前回高値を越えて、75＄位は時間の問題かなぁ\nと勝手に思っているんですけどね\n\n30＄台からの期待なので\nお取引されている方は\n結構大きなご利益に\nなっているのでは🎊\nビットコインには負けますが… https://t.co/ZoTH8WwFdc',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ZoTH8WwFdc',
#       'expanded_url': 'https://twitter.com/i/web/status/1387919586285084674',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1047081222298464256,
#     'id_str': '1047081222298464256',
#     'name': 'さくらインベスト',
#     'screen_name': 'Sakura_Invest',
#     'location': '上の情報は当社HPよりご覧いただけます。',
#     'description': '株式会社さくらインベストは商品先物取引業者です\n当社は一般的な金融リテラシーの向上の為に情報を発信しています\n◎金融リテラシーを学ぶ『Reてらこや』\n◎商品等をファンダ、テクニカルから分析『先物の極み』\n◎過去の投資セミナーを録画配信\n◎対面のオーダーメイドセミナーで知識を習得\nその他もろもろ拙い情報はここで発信！',
#     'url': 'https://t.co/ebgzGex5Ih',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ebgzGex5Ih',
#         'expanded_url': 'https://www.sakura-inv.com/',
#         'display_url': 'sakura-inv.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 912,
#     'friends_count': 56,
#     'listed_count': 15,
#     'created_at': 'Tue Oct 02 11:09:51 +0000 2018',
#     'favourites_count': 1575,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2439,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1318107246484549633/pM1Abk5D_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318107246484549633/pM1Abk5D_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1047081222298464256/1603169629',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:58:27 +0000 2021',
#    'id': 1387919240276037640,
#    'id_str': '1387919240276037640',
#    'text': 'ビットコイン暴落\n不安定な相場に投資するぐらいなら\nバイナリーで稼ぎませんか？\nhttps://t.co/JUUdhKlwut…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/JUUdhKlwut',
#       'expanded_url': 'http://jp.highlow.net/register?a_aid',
#       'display_url': 'jp.highlow.net/register?a_aid',
#       'indices': [40, 63]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 928174992436506625,
#     'id_str': '928174992436506625',
#     'name': 'はると',
#     'screen_name': '7yH23',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 420,
#     'friends_count': 513,
#     'listed_count': 1,
#     'created_at': 'Wed Nov 08 08:18:57 +0000 2017',
#     'favourites_count': 3,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8831,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/968059375980965889/p2OBg1eC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968059375980965889/p2OBg1eC_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:57:16 +0000 2021',
#    'id': 1387918939980587011,
#    'id_str': '1387918939980587011',
#    'text': '取引所間の価格差を利用して利益を得ましょう！ビットコインの相場が変わる限り利益を得ることが可能です！基軸通貨であるBTCが上がらないと他の通貨も上がらないです。BTCと日本円でアビトラをすることによって安定して稼げます。',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 978674360159387649,
#     'id_str': '978674360159387649',
#     'name': 'ゆうた',
#     'screen_name': 'yutahonto',
#     'location': '日本 大阪',
#     'description': '大阪大学 建築 仮想通貨 アビトラ 稼ぐ！日利0.5〜1%安定 最初に設定すれば後は放置するだけ！簡単に資金が増えます！ 日本円とBTCでアビトラします！',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1559,
#     'friends_count': 2801,
#     'listed_count': 0,
#     'created_at': 'Tue Mar 27 16:45:25 +0000 2018',
#     'favourites_count': 40,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10719,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/978674792009162753/Tc1Jdb_a_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978674792009162753/Tc1Jdb_a_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/978674360159387649/1522169289',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:56:28 +0000 2021',
#    'id': 1387918738276683786,
#    'id_str': '1387918738276683786',
#    'text': 'ビットコインはみんなの悲観が強く、ショートも集まりやすい展開なので、ここから上昇を想定します。イーサリアムは上がってしまってるので買いません。リップルは2週間の調整を終えて急騰を想定。Youtubeの方で解説しています。https://t.co/98lCPiQzH1',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/98lCPiQzH1',
#       'expanded_url': 'https://youtu.be/AyxvbopBGlo',
#       'display_url': 'youtu.be/AyxvbopBGlo',
#       'indices': [110, 133]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1343699166069985281,
#     'id_str': '1343699166069985281',
#     'name': '内科医まご@短期トレーダー',
#     'screen_name': '0jTlPw6KCE4HkBH',
#     'location': '',
#     'description': '副業で仮想通貨、FXの短期トレードをしてます。トレード歴2年、2020年12月にトータルプラスを達成。テクニカル分析を中心に、独自の視点での相場分析をお届けします。',
#     'url': 'https://t.co/uHo9pfywDe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/uHo9pfywDe',
#         'expanded_url': 'https://www.youtube.com/channel/UCIbERlEmRH6taVKyJFbcZmA',
#         'display_url': 'youtube.com/channel/UCIbER…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 513,
#     'friends_count': 5,
#     'listed_count': 3,
#     'created_at': 'Mon Dec 28 23:23:50 +0000 2020',
#     'favourites_count': 51,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 228,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1343699294369492992/KFQwGZ7b_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1343699294369492992/KFQwGZ7b_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1343699166069985281/1609383038',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 15,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:55:28 +0000 2021',
#    'id': 1387918488715542548,
#    'id_str': '1387918488715542548',
#    'text': '軟調推移のビットコイン、GW中は上昇するか？【仮想通貨相場】 https://t.co/A8BzdrV2Kd https://t.co/9hLYrfeEML',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/A8BzdrV2Kd',
#       'expanded_url': 'https://jp.cointelegraph.com/news/ct-japan-fx-coin-april-30th-2021',
#       'display_url': 'jp.cointelegraph.com/news/ct-japan-…',
#       'indices': [31, 54]}],
#     'media': [{'id': 1387918482575028231,
#       'id_str': '1387918482575028231',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/E0LggaMVcAcq2x_.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0LggaMVcAcq2x_.jpg',
#       'url': 'https://t.co/9hLYrfeEML',
#       'display_url': 'pic.twitter.com/9hLYrfeEML',
#       'expanded_url': 'https://twitter.com/Cypher_invest/status/1387918488715542548/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1160, 'h': 773, 'resize': 'fit'},
#        'medium': {'w': 1160, 'h': 773, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1387918482575028231,
#       'id_str': '1387918482575028231',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/E0LggaMVcAcq2x_.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0LggaMVcAcq2x_.jpg',
#       'url': 'https://t.co/9hLYrfeEML',
#       'display_url': 'pic.twitter.com/9hLYrfeEML',
#       'expanded_url': 'https://twitter.com/Cypher_invest/status/1387918488715542548/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1160, 'h': 773, 'resize': 'fit'},
#        'medium': {'w': 1160, 'h': 773, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://social-dog.net/" rel="nofollow">SocialDog for Twitter</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 996236587691261952,
#     'id_str': '996236587691261952',
#     'name': 'Satoshi@投資家',
#     'screen_name': 'Cypher_invest',
#     'location': '',
#     'description': '仮想通貨投資は2011年から｜最高月収5000万円 | 仮想通貨 | 株式 | CFD | 事業 | 3万円から2回億り人を経験 | 5ヶ月で30億円売り上げるも過去2年で4.5億円失う😂 | 現在資産10億円を目指して日々奮闘中🚀🚀🚀',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 383,
#     'friends_count': 621,
#     'listed_count': 1,
#     'created_at': 'Tue May 15 03:51:26 +0000 2018',
#     'favourites_count': 497,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5716,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1244642068447637504/wkZt9nhw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1244642068447637504/wkZt9nhw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/996236587691261952/1526356887',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:55:05 +0000 2021',
#    'id': 1387918389893492737,
#    'id_str': '1387918389893492737',
#    'text': '【satoshi】「1サトシ(Satoshi)」とはビットコインの発案者「サトシ・ナカモト」を由来とするビットコインの最小単位のことである。0.00000001BTC＝1サトシ(Satoshi)',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 948487571599908865,
#     'id_str': '948487571599908865',
#     'name': '仮想通貨【用語集】',
#     'screen_name': 'Bitcoin_beg',
#     'location': '',
#     'description': '初心者の為の仮想通貨 用語集です。仮想通貨の基礎知識からおすすめ通貨、最新情報までツイートしていきます。 おすすめの取引所⇨【https://t.co/A0yB9xqEWx】',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/A0yB9xqEWx',
#         'expanded_url': 'http://bitflyer.jp/?bf=wsp3vcfh',
#         'display_url': 'bitflyer.jp/?bf=wsp3vcfh',
#         'indices': [63, 86]}]}},
#     'protected': False,
#     'followers_count': 320,
#     'friends_count': 480,
#     'listed_count': 2,
#     'created_at': 'Wed Jan 03 09:33:53 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6880,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/948492735379488769/8EUJDVt0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948492735379488769/8EUJDVt0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/948487571599908865/1514973593',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:55:02 +0000 2021',
#    'id': 1387918377482526724,
#    'id_str': '1387918377482526724',
#    'text': '@vcnukko おはビットコイン！',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'vcnukko',
#       'name': 'ぬっこ',
#       'id': 124820333,
#       'id_str': '124820333',
#       'indices': [0, 8]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1387916674465103873,
#    'in_reply_to_status_id_str': '1387916674465103873',
#    'in_reply_to_user_id': 124820333,
#    'in_reply_to_user_id_str': '124820333',
#    'in_reply_to_screen_name': 'vcnukko',
#    'user': {'id': 1214472636253667328,
#     'id_str': '1214472636253667328',
#     'name': 'けにゃタンちゃんねる。',
#     'screen_name': 'KenyaChannel1',
#     'location': '',
#     'description': '音ゲーやMMOなどの配信、又は動画を作ってYouTubeにあげてます。 最近は、deemo cytus にはまっております。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 157,
#     'friends_count': 116,
#     'listed_count': 3,
#     'created_at': 'Tue Jan 07 09:03:46 +0000 2020',
#     'favourites_count': 8739,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2785,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1389215387653349381/wH42Rt-e_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1389215387653349381/wH42Rt-e_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1214472636253667328/1614515957',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Thu Apr 29 23:54:53 +0000 2021',
#    'id': 1387918340773924865,
#    'id_str': '1387918340773924865',
#    'text': '毎日50,000人以上があそぶ無料アプリ『ぴたコイン』で今すぐビットコインをゲットしよう！ここから登録するだけでもらえるよ\nhttps://t.co/7x2KiuLigF',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/7x2KiuLigF',
#       'expanded_url': 'https://pitacoin.page.link/SnBojeS5UeN4Y47G6',
#       'display_url': 'pitacoin.page.link/SnBojeS5UeN4Y4…',
#       'indices': [62, 85]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 127159400,
#     'id_str': '127159400',
#     'name': 'botanicaaa',
#     'screen_name': 'botanicaaa',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 151,
#     'friends_count': 2406,
#     'listed_count': 1,
#     'created_at': 'Sun Mar 28 07:38:02 +0000 2010',
#     'favourites_count': 105,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 14067,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.06,
#   'max_id': 1387919599698530304,
#   'max_id_str': '1387919599698530304',
#   'next_results': '?max_id=1387918340773924864&q=%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3%20until%3A2021-04-30%20exclude%3Aretweets&lang=ja&count=10&include_entities=1&result_type=recent',
#   'query': '%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3+until%3A2021-04-30+exclude%3Aretweets',
#   'refresh_url': '?since_id=1387919599698530304&q=%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3%20until%3A2021-04-30%20exclude%3Aretweets&lang=ja&result_type=recent&include_entities=1',
#   'count': 10,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
df_search = DataFrame.from_dict(search['statuses'])
tweets = df_search['text'].tolist()
tweets = normalize_tweets(tweets)
wakachi = get_wakachi(tweets, search_word)

# %%
# Initialize Negative-Positive Dictionary
pn_dic = {}
fp = open('../../lib/pn.csv', 'rt', encoding='utf-8')
reader = csv.reader(fp, delimiter='\t')
for i, row in enumerate(reader):
  name = row[0]
  result = row[1]
  pn_dic[name] = result

# %%
words_list = wakachi.split(' ')

# %%
cnt_p = 0
cnt_n = 0
cnt_e = 0

for word in words_list:
    pn = 'e'
    if word in pn_dic:
        pn = pn_dic[word]
    if pn == 'p':
        cnt_p += 1
    elif pn == 'n':
        cnt_n += 1
    else:
        cnt_e += 1
print('P:{}, N:{}, E:{}'.format(cnt_p, cnt_n, cnt_e))
# Out:
# P:266, N:37, E:1326

# %%
length = cnt_p + cnt_n
if length:
    pn = (cnt_p - cnt_n)/length
else:
    pn = 0

pn
# Out:
# 0.7557755775577558

# %%
from datetime import datetime

def date2str(date):
    return [date[i].strftime('%Y-%m-%d') for i in range(len(date))]

# %%
def getPN(words_list):
    cnt_p = 0
    cnt_n = 0
    cnt_e = 0

    for word in words_list:
        pn = 'e'
        if word in pn_dic:
            pn = pn_dic[word]
        if pn == 'p':
            cnt_p += 1
        elif pn == 'n':
            cnt_n += 1
        else:
            cnt_e += 1
    return cnt_p, cnt_n, cnt_e

# %%
end = datetime.now()
period = 365

date_list = pd.date_range(start=end, periods=period, freq='D')
date_list = date2str(date_list)

# %%
search_word = 'ビットコイン'
search_count = 10

list_p = []
list_n = []
list_e = []

# %%
for date in date_list:
    search = search_tweet_date(search_word, search_count, date, twitter)
    df_search = DataFrame.from_dict(search['statuses'])
    tweets = df_search['text'].tolist()
    tweets = normalize_tweets(tweets)
    wakachi = get_wakachi(tweets, search_word)
    words_list = wakachi.split(' ')
    p, n, e = getPN(words_list)
    list_p.append(p)
    list_n.append(n)
    list_e.append(e)
# Out:
# Error code: 429
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-82f4b8c9d325> in <module>
#       1 for date in date_list:
#       2     search = search_tweet_date(search_word, search_count, date, twitter)
# ----> 3     df_search = DataFrame.from_dict(search['statuses'])
#       4     tweets = df_search['text'].tolist()
#       5     tweets = normalize_tweets(tweets)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
len(list_p)
# Out:
# 172

# %%
for date in date_list[172:]:
    search = search_tweet_date(search_word, search_count, date, twitter)
    df_search = DataFrame.from_dict(search['statuses'])
    tweets = df_search['text'].tolist()
    tweets = normalize_tweets(tweets)
    wakachi = get_wakachi(tweets, search_word)
    words_list = wakachi.split(' ')
    p, n, e = getPN(words_list)
    list_p.append(p)
    list_n.append(n)
    list_e.append(e)
# Out:
# Error code: 429
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-fd154f13f9b7> in <module>
#       1 for date in date_list[172:]:
#       2     search = search_tweet_date(search_word, search_count, date, twitter)
# ----> 3     df_search = DataFrame.from_dict(search['statuses'])
#       4     tweets = df_search['text'].tolist()
#       5     tweets = normalize_tweets(tweets)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
len(list_p)
# Out:
# 349

# %%
for date in date_list[349:]:
    search = search_tweet_date(search_word, search_count, date, twitter)
    df_search = DataFrame.from_dict(search['statuses'])
    tweets = df_search['text'].tolist()
    tweets = normalize_tweets(tweets)
    wakachi = get_wakachi(tweets, search_word)
    words_list = wakachi.split(' ')
    p, n, e = getPN(words_list)
    list_p.append(p)
    list_n.append(n)
    list_e.append(e)

# %%
len(list_p)
# Out:
# 365

# %%
df_pn = DataFrame({'p':list_p, 'n':list_n, 'e':list_e}, index=date_list)
df_pn['p/n'] = (df_pn['p'] - df_pn['n'])/(df_pn['p'] + df_pn['n'])
df_pn
# Out:
#              p  n    e       p/n
# 2021-05-05  22  6  153  0.571429
# 2021-05-06  20  5  125  0.600000
# 2021-05-07  20  5  125  0.600000
# 2021-05-08  20  5  125  0.600000
# 2021-05-09  20  5  125  0.600000
# ...         .. ..  ...       ...
# 2022-04-30  22  7  158  0.517241
# 2022-05-01  22  7  158  0.517241
# 2022-05-02  22  7  158  0.517241
# 2022-05-03  22  7  158  0.517241
# 2022-05-04  22  7  158  0.517241
#
# [365 rows x 4 columns]

# %%
list_p
# Out:
# [22,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22]
