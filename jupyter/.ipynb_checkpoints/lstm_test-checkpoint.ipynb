# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns
import time
import sys
import datetime

import poloniex

from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.python.client import device_lib

sys.path.append('../')

import lstm

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12783593854284867890
# ]

# %%
dir_model = '../../Model/'

# %%
def plot_results_multiple(predicted_data, true_data, prediction_len):
    fig = plt.figure(facecolor='white')
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data, label='Prediction')
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.show()

# %%
coin = 'BTC'
data_len = 365 * 5

# %%
polo = poloniex.Poloniex()
period = polo.DAY # period of data
end = time.time()
start = end - period * (data_len + 50) # +50 to calcurate SMA50

chart = polo.returnChartData('USDT_%s'%coin, period=period, start=start, end=end)

# %%
df = DataFrame.from_dict(chart)
timestamp = df['date'].values.tolist() # Series -> ndarray -> list
# timestamp -> year/month/day
date = [datetime.datetime.fromtimestamp(timestamp[i]).date() for i in range(len(timestamp))]
df = df.astype(float)
df['date'] = date
df['timestamp'] = timestamp

# %%
df.drop(['quoteVolume', 'weightedAverage'], axis=1, inplace=True)
df['EMA20'] = df['close'].ewm(span=20).mean()
df['SMA50'] = df['close'].rolling(window=50).mean()
df['return'] = df['close'].pct_change()
df.head()
# Out:
#          date     high       low       open       close        volume  \
# 0  2016-04-01  417.000  417.0000  417.00000  417.000000      0.000000
# 1  2016-04-01  420.040  416.0000  416.00000  418.200000  12339.232686
# 2  2016-04-02  424.000  418.0000  418.59000  421.563015  68343.118542
# 3  2016-04-03  424.500  419.9191  419.91910  423.998998  65653.628557
# 4  2016-04-04  423.999  420.2000  421.90817  420.500008  26764.476461
#
#     timestamp       EMA20  SMA50    return
# 0  1459456966  417.000000    NaN       NaN
# 1  1459468800  417.630000    NaN  0.002878
# 2  1459555200  419.074180    NaN  0.008042
# 3  1459641600  420.495898    NaN  0.005778
# 4  1459728000  420.496892    NaN -0.008252

# %%
df[['close', 'EMA20', 'SMA50']].plot(subplots=False, figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
# Types of data used for estimate
data_type = ['close', 'EMA20', 'SMA50', 'volume', 'return']

# %%
data = df[data_type].values
data = np.nan_to_num(data)
data = data[-data_len:]
print('data shape: ', data.shape)
# Out:
# data shape:  (1825, 5)

# %%
# Normalization
norm_data = np.zeros_like(data)
for i in range(data.shape[1]):
    col = data[:, i]
    mean = np.mean(col)
    std = np.std(col)
    norm = (col - mean) / std
    norm_data[:, i] = norm

# %%
seq_len = 28
test_len = 56
gt_len=1

X_train, y_train, X_test, y_test = lstm.gen_data(
    norm_data, 
    seq_len, 
    gt_len=gt_len, 
    train_rate=(data_len-test_len)/data_len, 
    normalise_window=True
)
# Out:
# (1796, 29, 5)

# %%
print('Train length = ', X_train.shape[0])
print('Test length = ', X_test.shape[0])
# Out:
# Train length =  1741
# Test length =  55

# %%
input_ch = len(data_type)
hidden_layer = 300
output_ch = gt_len

model = lstm.build_model([input_ch, seq_len, hidden_layer, output_ch])

# %%
model_save_cb = ModelCheckpoint(dir_model + 'model-lstm_best.hdf5',
                                period=1,
                                monitor='val_loss',
                                save_best_only=True,
                                mode='min',
                                save_weights_only=True)
csv_logger_cb = CSVLogger(dir_model + 'model-lstm.log', append=False)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
epoch = 1000
model.fit(X_train, 
          y_train, 
          batch_size=64, 
          epochs=epoch, 
          shuffle=True,
          validation_split=0.2, 
          callbacks=[model_save_cb, csv_logger_cb],
          verbose=0)
model.save_weights(dir_model + 'model-lstm_final.hdf5')

# %%
df_log = pd.read_csv(dir_model + 'model-lstm.log')
df_log[['loss', 'val_loss']].plot(subplots=False, figsize=(15, 5))
plt.ylim(0, 0.05)
# Out:
# (0.0, 0.05)

# %%
pred_len = 7
model.load_weights(dir_model + 'model-lstm_best.hdf5')
predictions = lstm.predict_sequences_multiple(model, X_test, seq_len, pred_len)

# %%
plot_results_multiple(predictions, y_test, pred_len)

# %%
model.load_weights(dir_model + 'model-lstm_final.hdf5')
predictions = lstm.predict_sequences_multiple(model, X_test, seq_len, pred_len)

# %%
plot_results_multiple(predictions, y_test, pred_len)

# %%
plt.plot(data[-test_len:, 0])
