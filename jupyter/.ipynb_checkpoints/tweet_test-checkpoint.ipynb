# %%
import json
from requests_oauthlib import OAuth1Session

# %%
def tweet(oauth, text):
    url = 'https://api.twitter.com/1.1/statuses/update.json'
    params = {'status': text + '\n#TweetFromPy'}
    req = oauth.post(url, params)

    if req.status_code == 200:
        print('tweet succeed!')
    else:
        print('tweet failed')

# %%
def create_oauth_session(oauth_key_dict):
    oauth = OAuth1Session(
        oauth_key_dict['consumer_key'],
        oauth_key_dict['consumer_secret'],
        oauth_key_dict['access_token'],
        oauth_key_dict['access_token_secret']
    )
    return oauth

# %%
keysfile = '../../twitter_API/key/keys.json'
keys = json.load(open(keysfile))
oauth = create_oauth_session(keys)

# %%
text = 'test'

tweet(oauth, text)
# Out:
# tweet succeed!

# %%
def tweet_search(search_word, num, oauth):
    url = 'https://api.twitter.com/1.1/search/tweets.json'
    params = {
        'q': search_word,
        'count' : num,
        'result_type' : 'recent',
        'exclude': 'retweets',
        'lang' : 'ja'
        }
    responce = oauth.get(url, params=params)
    if responce.status_code != 200:
        print("Error code: %d" %(responce.status_code))
        return None
    tweets = json.loads(responce.text)
    return tweets

# %%
tweets = tweet_search("Bitcoin", 10, oauth)
tweets
# Out:
# {'statuses': [{'created_at': 'Mon May 03 09:32:07 +0000 2021',
#    'id': 1389150771699077121,
#    'id_str': '1389150771699077121',
#    'text': 'ZaifスマートATMやLocalBitcoinsなどと違い、双方が対等な関係でBitcoinなどの暗号通貨の売買ができるサイトです。\n\n「手数料の安さと、匿名性のどちらも大事」という方におすすめです。\n\nhttps://t.co/bYqAjn9t1E\n\n#暗号通貨',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '暗号通貨', 'indices': [128, 133]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/bYqAjn9t1E',
#       'expanded_url': 'http://btctrade.web.fc2.com/',
#       'display_url': 'btctrade.web.fc2.com',
#       'indices': [103, 126]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4674271638,
#     'id_str': '4674271638',
#     'name': 'btc-trade-p2p',
#     'screen_name': 'btctradep2p',
#     'location': '',
#     'description': 'Bitcoin、Litecoin、DASH、Monacoinを現金で個人間で簡単に対面売買することができるサイト、btc-trade-p2pの運営をしております。ご質問などがあれば、お気軽にどうぞ。よろしくお願いします。重要な通知用アカウント→@btctradep2p_i\u3000#暗号通貨 #Bitcoin #ビットコイン',
#     'url': 'https://t.co/ITDaFRnrWq',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ITDaFRnrWq',
#         'expanded_url': 'http://btctrade.web.fc2.com/',
#         'display_url': 'btctrade.web.fc2.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1913,
#     'friends_count': 572,
#     'listed_count': 104,
#     'created_at': 'Tue Dec 29 19:44:10 +0000 2015',
#     'favourites_count': 25,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 68170,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/687167690423701504/Rp2x9cje_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/687167690423701504/Rp2x9cje_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:30:56 +0000 2021',
#    'id': 1389150472544653313,
#    'id_str': '1389150472544653313',
#    'text': 'ビットコインがTaprootでよりプライバシー強化されるかも👀マイナーさんアプデお願いします🚀🔥\nhttps://t.co/CnTiZyejVR',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/CnTiZyejVR',
#       'expanded_url': 'https://www.coindesk.com/bitcoin-taproot-activation-begun-miners-3-months-onboard',
#       'display_url': 'coindesk.com/bitcoin-taproo…',
#       'indices': [49, 72]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 267810893,
#     'id_str': '267810893',
#     'name': 'Yusuke',
#     'screen_name': 'coinclubjapan',
#     'location': 'London',
#     'description': '東京→ニューヨーク→ロンドン(現在)\u3000のんびりセミリタイア中',
#     'url': 'https://t.co/sfm7JidPjE',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/sfm7JidPjE',
#         'expanded_url': 'https://www.youtube.com/channel/UCWhemq3KH46mgbPfUOg4Brg',
#         'display_url': 'youtube.com/channel/UCWhem…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 10671,
#     'friends_count': 143,
#     'listed_count': 56,
#     'created_at': 'Thu Mar 17 15:47:26 +0000 2011',
#     'favourites_count': 1276,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2624,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1051544333512372224/1lT_-1wh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051544333512372224/1lT_-1wh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/267810893/1615452923',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 8,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:30:11 +0000 2021',
#    'id': 1389150282399948804,
#    'id_str': '1389150282399948804',
#    'text': '6万ドルのぬりかべ〜〜🤑\n…Bitcoin\n今年も楽しくなりそうです。\nもう半分終わったが（笑）\n\nまだ半分あるって思いたい時と\nもう半分終わったぜー、ふー♪\n\nその日の気分によりけり😁\n\nお金のことを考えると圧倒的に後者w',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1243187668470521858,
#     'id_str': '1243187668470521858',
#     'name': 'ハーベスターおきし@お金について猛勉強中',
#     'screen_name': 'okeyshichan',
#     'location': '',
#     'description': '長所は運が良いところです。最近興味がある事は暗号資産です\u20bfよろしくどうぞっ✌︎ 2021年の目標は資産を8桁にすることです（本気）お金に好かれる人生でありたい💴お金と両思いになりたい👩🏻💛💴お金のこと沢山勉強して人生を豊かにするのじゃ🙆\u200d♀️そう決めたのだ',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45,
#     'friends_count': 79,
#     'listed_count': 0,
#     'created_at': 'Thu Mar 26 14:47:07 +0000 2020',
#     'favourites_count': 1062,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1130,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1366145880370212864/xsY3UdJP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1366145880370212864/xsY3UdJP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1243187668470521858/1588156183',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:30:06 +0000 2021',
#    'id': 1389150264674820097,
#    'id_str': '1389150264674820097',
#    'text': '取引手数料20%還元を謳っている方がいらっしゃいますが、招待IDを入力した際に還元率が表示されないものはキャッシュバックが貰えないので気をつけて下さい。\n\n招待ID:Z1PV5QQZ\n\n#招待ID\n#紹介\n#クーポン\n#バイナンス… https://t.co/K6z2NovndG',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': '招待ID', 'indices': [93, 98]},
#      {'text': '紹介', 'indices': [99, 102]},
#      {'text': 'クーポン', 'indices': [103, 108]},
#      {'text': 'バイナンス', 'indices': [109, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/K6z2NovndG',
#       'expanded_url': 'https://twitter.com/i/web/status/1389150264674820097',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/rickbox_" rel="nofollow">get-access-token-rickbox</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1177442815728472064,
#     'id_str': '1177442815728472064',
#     'name': 'バイナンス 招待ID',
#     'screen_name': 'binanceJP__',
#     'location': '',
#     'description': '招待ID入力で全取引の手数料が10%キャッシュバックされます。 招待ID:Z1PV5QQZ 以下のリンクから登録できます↓↓',
#     'url': 'https://t.co/bFGoA7OZIZ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/bFGoA7OZIZ',
#         'expanded_url': 'https://accounts.binance.com/ja/register?ref=Z1PV5QQZ',
#         'display_url': 'accounts.binance.com/ja/register?re…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45,
#     'friends_count': 8,
#     'listed_count': 1,
#     'created_at': 'Fri Sep 27 04:40:24 +0000 2019',
#     'favourites_count': 80,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1247,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1372027050177961987/fNRmU0bz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1372027050177961987/fNRmU0bz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1177442815728472064/1615951776',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:30:04 +0000 2021',
#    'id': 1389150253027258368,
#    'id_str': '1389150253027258368',
#    'text': '現在の価格は 6,427,327.5円です。前回比は-18,572.5円(-0.29%)です。 #ビットコイン #bitcoin #btc $BTCJPY via @bitFlyer #ブロックチェーン',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ビットコイン', 'indices': [48, 55]},
#      {'text': 'bitcoin', 'indices': [56, 64]},
#      {'text': 'btc', 'indices': [65, 69]},
#      {'text': 'ブロックチェーン', 'indices': [92, 101]}],
#     'symbols': [{'text': 'BTCJPY', 'indices': [70, 77]}],
#     'user_mentions': [{'screen_name': 'bitFlyer',
#       'name': 'bitFlyer（ビットフライヤー）',
#       'id': 2291828892,
#       'id_str': '2291828892',
#       'indices': [82, 91]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://www.mmtandcompany.com" rel="nofollow">bitcoinjp Tweet</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1877257982,
#     'id_str': '1877257982',
#     'name': 'ビットコイン円相場',
#     'screen_name': 'bitcoinjp',
#     'location': '東京',
#     'description': '#bitcoin #ビットコイン を始め #仮想通貨 に関する国内外の最新ニュースに加え $BTCJPY の最新価格を表示。30分毎に最新の価格をツイート。他にも経済やその他気になるニュースのつぶやきやRTを行っています。コラボや広告のお問い合わせはDMにて。For an inquiry, please DM us📬',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 17532,
#     'friends_count': 31,
#     'listed_count': 222,
#     'created_at': 'Tue Sep 17 23:16:57 +0000 2013',
#     'favourites_count': 509,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 162353,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1389150253840945157/hsZoRj0Y_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1389150253840945157/hsZoRj0Y_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1877257982/1470969294',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:29:23 +0000 2021',
#    'id': 1389150081090080770,
#    'id_str': '1389150081090080770',
#    'text': 'CALOTTO SPECIALの事前登録フォーム画面が出来上がってきました🙆\u200d♂️👍🏻\n\nこのフォームから登録することで、無条件で3000円分のポイントがもらえるキャンペーンにパワーUP!!!🎉✨\n\n詳細をお楽しみに...🌟… https://t.co/8eW9fF0QVp',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/8eW9fF0QVp',
#       'expanded_url': 'https://twitter.com/i/web/status/1389150081090080770',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1379663557197893632,
#     'id_str': '1379663557197893632',
#     'name': 'CALOTTO(キャロット) -スマホで完結!!オンライン宝くじ-',
#     'screen_name': 'Calotto_lotto',
#     'location': '',
#     'description': 'CALOTTO(キャロット)は〜毎週3億円〜が誰かに当たる!!🎉 規格外のアジア発オンライン宝くじです🐰 近日オープンにつき、公式アカウントオープン!! 最新情報やキャンペーンなど配信🎁✨',
#     'url': 'https://t.co/U95zPJRvfQ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/U95zPJRvfQ',
#         'expanded_url': 'https://www.instagram.com/calotto_lotto',
#         'display_url': 'instagram.com/calotto_lotto',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 196,
#     'friends_count': 816,
#     'listed_count': 4,
#     'created_at': 'Wed Apr 07 05:13:37 +0000 2021',
#     'favourites_count': 1837,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 32,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1379663683127664640/y09377eK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1379663683127664640/y09377eK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1379663557197893632/1618050880',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:27:59 +0000 2021',
#    'id': 1389149729829781506,
#    'id_str': '1389149729829781506',
#    'text': '【ビットコイン 24時間変動比】+4.26% (+262495) 6420351 #仮想通貨 #暗号通貨 #bitFlyer #ビットフライヤー https://t.co/Xrk2FGJlVl  https://t.co/QsmrS0wYq3',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '仮想通貨', 'indices': [41, 46]},
#      {'text': '暗号通貨', 'indices': [47, 52]},
#      {'text': 'bitFlyer', 'indices': [53, 62]},
#      {'text': 'ビットフライヤー', 'indices': [63, 72]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/QsmrS0wYq3',
#       'expanded_url': 'https://sekai-kabuka.com/bitcoin.html',
#       'display_url': 'sekai-kabuka.com/bitcoin.html',
#       'indices': [98, 121]}],
#     'media': [{'id': 1389149713790734339,
#       'id_str': '1389149713790734339',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/media/E0dATf5VEAMV8hE.png',
#       'media_url_https': 'https://pbs.twimg.com/media/E0dATf5VEAMV8hE.png',
#       'url': 'https://t.co/Xrk2FGJlVl',
#       'display_url': 'pic.twitter.com/Xrk2FGJlVl',
#       'expanded_url': 'https://twitter.com/monokutoa/status/1389149714646327304/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 155, 'resize': 'fit'},
#        'large': {'w': 751, 'h': 171, 'resize': 'fit'},
#        'medium': {'w': 751, 'h': 171, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}},
#       'source_status_id': 1389149714646327304,
#       'source_status_id_str': '1389149714646327304',
#       'source_user_id': 187150074,
#       'source_user_id_str': '187150074'}]},
#    'extended_entities': {'media': [{'id': 1389149713790734339,
#       'id_str': '1389149713790734339',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/media/E0dATf5VEAMV8hE.png',
#       'media_url_https': 'https://pbs.twimg.com/media/E0dATf5VEAMV8hE.png',
#       'url': 'https://t.co/Xrk2FGJlVl',
#       'display_url': 'pic.twitter.com/Xrk2FGJlVl',
#       'expanded_url': 'https://twitter.com/monokutoa/status/1389149714646327304/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 155, 'resize': 'fit'},
#        'large': {'w': 751, 'h': 171, 'resize': 'fit'},
#        'medium': {'w': 751, 'h': 171, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}},
#       'source_status_id': 1389149714646327304,
#       'source_status_id_str': '1389149714646327304',
#       'source_user_id': 187150074,
#       'source_user_id_str': '187150074'}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 261202564,
#     'id_str': '261202564',
#     'name': 'kyookine',
#     'screen_name': 'kyookine',
#     'location': 'Chiba\u3000Japan',
#     'description': '米国を中心に海外の相場関連のニュース・市況を、個人的に相場で収益を得るためにツイート。\nタイムラインの価値向上に注力。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2820,
#     'friends_count': 197,
#     'listed_count': 77,
#     'created_at': 'Sat Mar 05 13:21:56 +0000 2011',
#     'favourites_count': 29758,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 161240,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/464266705313615872/PpryEcou_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/464266705313615872/PpryEcou_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/261202564/1399521469',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:25:23 +0000 2021',
#    'id': 1389149075749183494,
#    'id_str': '1389149075749183494',
#    'text': 'May 3, 2021 at 06:25PMのビットコインの価格は 6415327.5円です。 #Bitcoin',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [48, 56]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3998731,
#     'id_str': '3998731',
#     'name': 'しんちゃん®',
#     'screen_name': 'susamishin',
#     'location': 'Japan',
#     'description': '愛車 #Cervélo S3 R3 C3を所有。Cyclist。🚴\n#映画 #音楽 #DTM 🔰\u3000\n#DAW は #Cubase\n#Scuba #Diving（ #CMAS OW）\n#Camera #Cannon #PS5 🎮\n東証2017年4月入学 適当凍死化 #オートレ225\n広く浅く、太く短く。👍',
#     'url': 'https://t.co/ZF2UQyw1H6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ZF2UQyw1H6',
#         'expanded_url': 'http://www.superblog.jp/',
#         'display_url': 'superblog.jp',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1031,
#     'friends_count': 1254,
#     'listed_count': 74,
#     'created_at': 'Tue Apr 10 07:51:03 +0000 2007',
#     'favourites_count': 38160,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 206509,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1371623816854609921/ggV0EunC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1371623816854609921/ggV0EunC_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3998731/1594964368',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:25:14 +0000 2021',
#    'id': 1389149038084333569,
#    'id_str': '1389149038084333569',
#    'text': '#仮想通貨 #VEE\nBittrex高騰/暴落 速報(5分前価格と???較)\n[BTC-VEE]-8.33%0.000000110\n[BTC-VRC]7.23%0.000002520\n\nhttps://t.co/OsxgzFz1EL',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '仮想通貨', 'indices': [0, 5]},
#      {'text': 'VEE', 'indices': [6, 10]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/OsxgzFz1EL',
#       'expanded_url': 'https://www.youtube.com/watch?v=xAUuC1Yx3AU',
#       'display_url': 'youtube.com/watch?v=xAUuC1…',
#       'indices': [93, 116]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://www.cointarget.net/" rel="nofollow">仮想通貨攻略</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 943151834063028224,
#     'id_str': '943151834063028224',
#     'name': 'ボンボン@仮想通貨攻略',
#     'screen_name': 'mmm_bitcoin_mmm',
#     'location': '日本',
#     'description': '仮想通貨情報を収集しています。 通貨の高騰・暴落速報も発信していきたいと思います。\n5分間隔でデータを取得して分析していますお役に立てて下さい。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 856,
#     'friends_count': 39,
#     'listed_count': 6,
#     'created_at': 'Tue Dec 19 16:11:34 +0000 2017',
#     'favourites_count': 65,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 200160,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/943154027411357698/9kEKV3F3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943154027411357698/9kEKV3F3_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Mon May 03 09:25:05 +0000 2021',
#    'id': 1389149001157537795,
#    'id_str': '1389149001157537795',
#    'text': '招待コード入力で全取引の手数料が20%キャッシュバックされます。\n\n招待ID:16379207\n\n#招待ID\n#紹介\n#クーポン\n#バイナンス\n#仮想通貨\n#ビットコイン\n#Bitcoin\n#Binance\n#IOST\n18:25',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '招待ID', 'indices': [49, 54]},
#      {'text': '紹介', 'indices': [55, 58]},
#      {'text': 'クーポン', 'indices': [59, 64]},
#      {'text': 'バイナンス', 'indices': [65, 71]},
#      {'text': '仮想通貨', 'indices': [72, 77]},
#      {'text': 'ビットコイン', 'indices': [78, 85]},
#      {'text': 'Bitcoin', 'indices': [86, 94]},
#      {'text': 'Binance', 'indices': [95, 103]},
#      {'text': 'IOST', 'indices': [104, 109]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/rickbox_" rel="nofollow">get-access-token-rickbox</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1387344814497173505,
#     'id_str': '1387344814497173505',
#     'name': 'バイナンス 招待コード 20% 還元',
#     'screen_name': 'binance______id',
#     'location': '',
#     'description': '招待コード入力で全取引の手数料が20%キャッシュバックされます。以下のリンクから登録できます↓↓',
#     'url': 'https://t.co/sGWEED5Vpb',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/sGWEED5Vpb',
#         'expanded_url': 'https://www.binance.cc/ja/register?ref=16379207',
#         'display_url': 'binance.cc/ja/register?re…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 10,
#     'friends_count': 3,
#     'listed_count': 0,
#     'created_at': 'Wed Apr 28 09:56:05 +0000 2021',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 103,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1387344973880651782/n7CPxFM0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1387344973880651782/n7CPxFM0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1387344814497173505/1619603999',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.057,
#   'max_id': 1389150771699077121,
#   'max_id_str': '1389150771699077121',
#   'next_results': '?max_id=1389149001157537794&q=Bitcoin%20exclude%3Aretweets&lang=ja&count=10&include_entities=1&result_type=recent',
#   'query': 'Bitcoin+exclude%3Aretweets',
#   'refresh_url': '?since_id=1389150771699077121&q=Bitcoin%20exclude%3Aretweets&lang=ja&result_type=recent&include_entities=1',
#   'count': 10,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df = DataFrame.from_dict(tweets['statuses'])
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Mon May 03 09:32:07 +0000 2021  1389150771699077121  1389150771699077121
# 1  Mon May 03 09:30:56 +0000 2021  1389150472544653313  1389150472544653313
# 2  Mon May 03 09:30:11 +0000 2021  1389150282399948804  1389150282399948804
# 3  Mon May 03 09:30:06 +0000 2021  1389150264674820097  1389150264674820097
# 4  Mon May 03 09:30:04 +0000 2021  1389150253027258368  1389150253027258368
#
#                                                 text  truncated  \
# 0  ZaifスマートATMやLocalBitcoinsなどと違い、双方が対等な関係でBitcoi...      False
# 1  ビットコインがTaprootでよりプライバシー強化されるかも👀マイナーさんアプデお願いします...      False
# 2  6万ドルのぬりかべ〜〜🤑\n…Bitcoin\n今年も楽しくなりそうです。\nもう半分終わっ...      False
# 3  取引手数料20%還元を謳っている方がいらっしゃいますが、招待IDを入力した際に還元率が表示さ...       True
# 4  現在の価格は 6,427,327.5円です。前回比は-18,572.5円(-0.29%)です...      False
#
#                                             entities  \
# 0  {'hashtags': [{'text': '暗号通貨', 'indices': [128...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [{'text': '招待ID', 'indices': [93,...
# 4  {'hashtags': [{'text': 'ビットコイン', 'indices': [4...
#
#                                             metadata  \
# 0  {'iso_language_code': 'ja', 'result_type': 're...
# 1  {'iso_language_code': 'ja', 'result_type': 're...
# 2  {'iso_language_code': 'ja', 'result_type': 're...
# 3  {'iso_language_code': 'ja', 'result_type': 're...
# 4  {'iso_language_code': 'ja', 'result_type': 're...
#
#                                               source in_reply_to_status_id  \
# 0  <a href="http://twittbot.net/" rel="nofollow">...                  None
# 1  <a href="https://mobile.twitter.com" rel="nofo...                  None
# 2  <a href="http://twitter.com/download/iphone" r...                  None
# 3  <a href="https://twitter.com/rickbox_" rel="no...                  None
# 4  <a href="http://www.mmtandcompany.com" rel="no...                  None
#
#   in_reply_to_status_id_str  ... place contributors is_quote_status  \
# 0                      None  ...  None         None           False
# 1                      None  ...  None         None           False
# 2                      None  ...  None         None           False
# 3                      None  ...  None         None           False
# 4                      None  ...  None         None           False
#
#   retweet_count favorite_count favorited retweeted possibly_sensitive  lang  \
# 0             0              0     False     False              False    ja
# 1             1              8     False     False              False    ja
# 2             0              0     False     False                NaN    ja
# 3             0              1     False     False                NaN    ja
# 4             0              1     False     False                NaN    ja
#
#    extended_entities
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 26 columns]

# %%
df = df['text']
df.head()
# Out:
# 0    ZaifスマートATMやLocalBitcoinsなどと違い、双方が対等な関係でBitcoi...
# 1    ビットコインがTaprootでよりプライバシー強化されるかも👀マイナーさんアプデお願いします...
# 2    6万ドルのぬりかべ〜〜🤑\n…Bitcoin\n今年も楽しくなりそうです。\nもう半分終わっ...
# 3    取引手数料20%還元を謳っている方がいらっしゃいますが、招待IDを入力した際に還元率が表示さ...
# 4    現在の価格は 6,427,327.5円です。前回比は-18,572.5円(-0.29%)です...
# Name: text, dtype: object
