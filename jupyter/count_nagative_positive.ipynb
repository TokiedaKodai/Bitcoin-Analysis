# %%
import pandas as pd
from pandas import Series, DataFrame
import json
from janome.tokenizer import Tokenizer
from requests_oauthlib import OAuth1Session
from wordcloud import WordCloud
import emoji
import re
import csv

# %%
def create_oauth_session(oauth_key_dict):
    oauth = OAuth1Session(
        oauth_key_dict['consumer_key'],
        oauth_key_dict['consumer_secret'],
        oauth_key_dict['access_token'],
        oauth_key_dict['access_token_secret']
    )
    return oauth

def search_tweet(word, count, oauth):
    url = 'https://api.twitter.com/1.1/search/tweets.json'
    params = {
        'q': word,
        'count' : count,
        'result_type' : 'recent',
        'exclude': 'retweets',
        'lang' : 'ja'
        }
    responce = oauth.get(url, params=params)
    if responce.status_code != 200:
        print("Error code: %d" %(responce.status_code))
        return None
    tweets = json.loads(responce.text)
    return tweets

def search_tweet_date(word, count, date, oauth):
    url = 'https://api.twitter.com/1.1/search/tweets.json'
    params = {
        'q': word,
        'count' : count,
        'result_type' : 'recent',
        'until' : date,
        'exclude': 'retweets',
        'lang' : 'ja'
        }
    responce = oauth.get(url, params=params)
    if responce.status_code != 200:
        print("Error code: %d" %(responce.status_code))
        return None
    tweets = json.loads(responce.text)
    return tweets

# %%
def remove_emoji(text):
    return ''.join(c for c in text if c not in emoji.UNICODE_EMOJI['en'])

def remove_url(text):
    return re.sub(r'https?://[\w/:%#\$&\?\(\)~\.=\+\-]+', '', text)
# Get Wakachigaki
def get_wakachi(list_text, word, hinshi=['名詞', '形容詞']):
    remove_words = ['こと', 'よう', 'そう', 'これ', 'それ', 'もの', 'ここ', 'さん', 'ちゃん',
                'ところ', 'とこ', 'の', 'ん', word]
    t = Tokenizer()
    wakachi = ''
    for text in list_text:
        malist = t.tokenize(text)
        for w in malist:
            word = w.surface
            part = w.part_of_speech
            hit = False
            for h in hinshi:
                hit = hit or (h in part)
            if not hit:
                continue
            if word not in remove_words:
                wakachi += word + ' '
    return wakachi

# %%
# Tweet Normalization
def normalize_tweets(tweets):
    normalized = []
    for tweet in tweets:
        text = tweet
        text = remove_emoji(text)
        text = remove_url(text)
        normalized.append(text)
    return normalized

# %%
keysfile = '../../twitter_API/key/keys.json'
keys = json.load(open(keysfile))
twitter = create_oauth_session(keys)

# %%
search_word = 'ビットコイン'
search_count = 10
date = '2021-04-27'

search = search_tweet_date(search_word, search_count, date, twitter)
search
# Out:
# {'statuses': [],
#  'search_metadata': {'completed_in': 0.009,
#   'max_id': 1389955937226555392,
#   'max_id_str': '1389955937226555392',
#   'query': '%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3+until%3A2021-04-27+exclude%3Aretweets',
#   'refresh_url': '?since_id=1389955937226555392&q=%E3%83%93%E3%83%83%E3%83%88%E3%82%B3%E3%82%A4%E3%83%B3%20until%3A2021-04-27%20exclude%3Aretweets&lang=ja&result_type=recent&include_entities=1',
#   'count': 10,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
df_search = DataFrame.from_dict(search['statuses'])
tweets = df_search['text'].tolist()
tweets = normalize_tweets(tweets)
wakachi = get_wakachi(tweets, search_word)

# %%
# Initialize Negative-Positive Dictionary
pn_dic = {}
fp = open('../../lib/pn.csv', 'rt', encoding='utf-8')
reader = csv.reader(fp, delimiter='\t')
for i, row in enumerate(reader):
  name = row[0]
  result = row[1]
  pn_dic[name] = result

# %%
words_list = wakachi.split(' ')

# %%
cnt_p = 0
cnt_n = 0
cnt_e = 0

for word in words_list:
    pn = 'e'
    if word in pn_dic:
        pn = pn_dic[word]
    if pn == 'p':
        cnt_p += 1
    elif pn == 'n':
        cnt_n += 1
    else:
        cnt_e += 1
print('P:{}, N:{}, E:{}'.format(cnt_p, cnt_n, cnt_e))
# Out:
# P:22, N:15, E:119

# %%
length = cnt_p + cnt_n
if length:
    pn = (cnt_p - cnt_n)/length
else:
    pn = 0

pn
# Out:
# 0.1891891891891892

# %%
from datetime import datetime

def date2str(date):
    return [date[i].strftime('%Y-%m-%d') for i in range(len(date))]

# %%
def getPN(words_list):
    cnt_p = 0
    cnt_n = 0
    cnt_e = 0

    for word in words_list:
        pn = 'e'
        if word in pn_dic:
            pn = pn_dic[word]
        if pn == 'p':
            cnt_p += 1
        elif pn == 'n':
            cnt_n += 1
        else:
            cnt_e += 1
    return cnt_p, cnt_n, cnt_e

# %%
end = datetime.now()
period = 365

date_list = pd.date_range(end=end, periods=period, freq='D')
date_list = date2str(date_list)

# %%
search_word = 'ビットコイン'
search_count = 100

list_p = []
list_n = []
list_e = []

# %%
for date in date_list:
    search = search_tweet_date(search_word, search_count, date, twitter)
    df_search = DataFrame.from_dict(search['statuses'])
    tweets = df_search['text'].tolist()
    tweets = normalize_tweets(tweets)
    wakachi = get_wakachi(tweets, search_word)
    words_list = wakachi.split(' ')
    p, n, e = getPN(words_list)
    list_p.append(p)
    list_n.append(n)
    list_e.append(e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\btc_analysis\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-82f4b8c9d325> in <module>
#       2     search = search_tweet_date(search_word, search_count, date, twitter)
#       3     df_search = DataFrame.from_dict(search['statuses'])
# ----> 4     tweets = df_search['text'].tolist()
#       5     tweets = normalize_tweets(tweets)
#       6     wakachi = get_wakachi(tweets, search_word)
#
# ~\Anaconda3\envs\btc_analysis\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda3\envs\btc_analysis\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'text'

# %%
search_word = '猫'
search = search_tweet_date(search_word, search_count, '2015-07-19', twitter)
search
# Out:
# {'statuses': [{'created_at': 'Wed May 05 14:37:02 +0000 2021',
#    'id': 1389952281940877314,
#    'id_str': '1389952281940877314',
#    'text': '@gyuuuunyuuuumow うちの猫の誕生日です。\nもしかしてうちの仔…元奥さん…❓',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gyuuuunyuuuumow',
#       'name': 'うしがにげた。',
#       'id': 1221391154987458560,
#       'id_str': '1221391154987458560',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389905622309773313,
#    'in_reply_to_status_id_str': '1389905622309773313',
#    'in_reply_to_user_id': 1221391154987458560,
#    'in_reply_to_user_id_str': '1221391154987458560',
#    'in_reply_to_screen_name': 'gyuuuunyuuuumow',
#    'user': {'id': 1263446143616208899,
#     'id_str': '1263446143616208899',
#     'name': 'かにみそ',
#     'screen_name': 'kanimiso_0505',
#     'location': '千葉県',
#     'description': '元酪農ヘルパーで酪農家の嫁で三姉妹の母。 万年ダイエッター。お笑い芸人のラジオを聴きながら仕事してます。いい加減で言いっぱなしのアカウント❤️フォロワーさんで盛り上がってくださる時がありますが私抜きでも是非お楽しみ下さい❤️',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 204,
#     'friends_count': 293,
#     'listed_count': 2,
#     'created_at': 'Thu May 21 12:26:58 +0000 2020',
#     'favourites_count': 17126,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3039,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1388808290180554758/ZE6JvUBx_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1388808290180554758/ZE6JvUBx_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1263446143616208899/1620123214',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:02 +0000 2021',
#    'id': 1389952281198485505,
#    'id_str': '1389952281198485505',
#    'text': 'トキにゃん…………??????\n\n猫と言えばミツザネゴトクネコカシャチェシャ……あとなんか居たっけ？',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1389951655962058755,
#    'in_reply_to_status_id_str': '1389951655962058755',
#    'in_reply_to_user_id': 1334727991864127488,
#    'in_reply_to_user_id_str': '1334727991864127488',
#    'in_reply_to_screen_name': 'gkp20080731',
#    'user': {'id': 1334727991864127488,
#     'id_str': '1334727991864127488',
#     'name': '爆死ン王kaede',
#     'screen_name': 'gkp20080731',
#     'location': 'イシュタリア、エデン大陸',
#     'description': '不定期に虚無\nお別れ方法はおまかせで（ブロ解が個人的に1番気が楽）\nよくツイ消しする（なんかごちゃごちゃしたの嫌い）\n絵→@prnra_H',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 80,
#     'friends_count': 112,
#     'listed_count': 2,
#     'created_at': 'Fri Dec 04 05:16:09 +0000 2020',
#     'favourites_count': 13,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 879,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1388039252760358913/pIwjpJg0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1388039252760358913/pIwjpJg0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1334727991864127488/1620221524',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:01 +0000 2021',
#    'id': 1389952277457162242,
#    'id_str': '1389952277457162242',
#    'text': '@xu5OpBLqRzQAnde いつもはトラちゃんが寝てるんだけど、他で寝てる時横取りして寝てます🐱\n他の猫ちゃんも狙ってるので空いてたら取られちゃいます。\n因みにクロちゃんは1番デカイかも',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'xu5OpBLqRzQAnde',
#       'name': 'チョコ太郎',
#       'id': 1189531545301733377,
#       'id_str': '1189531545301733377',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389943019005042688,
#    'in_reply_to_status_id_str': '1389943019005042688',
#    'in_reply_to_user_id': 1189531545301733377,
#    'in_reply_to_user_id_str': '1189531545301733377',
#    'in_reply_to_screen_name': 'xu5OpBLqRzQAnde',
#    'user': {'id': 574481381,
#     'id_str': '574481381',
#     'name': 'meg',
#     'screen_name': 'softbank_22',
#     'location': '由利本荘市',
#     'description': '家ネコ14匹とノラ猫2匹のウンコ片付け係やってます🥺 ほぼ独り言ですが、気軽にフォローしてくださいませ😋 無言フォロー失礼します。イマイチ使い方不慣れななんで、ご指導下さいませ',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 91,
#     'friends_count': 187,
#     'listed_count': 0,
#     'created_at': 'Tue May 08 13:37:37 +0000 2012',
#     'favourites_count': 1330,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1976,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1200648260433543168/vpaDFIYa_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1200648260433543168/vpaDFIYa_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/574481381/1575091828',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:01 +0000 2021',
#    'id': 1389952276752596996,
#    'id_str': '1389952276752596996',
#    'text': '@hana_with_coro んで、猫らーずの主張に負け、現在ちびらーずは、家に上がって子育て中。\nうちの猫のはずのミータくんは、どこへお出かけやらです。🐈🐈\u200d⬛😅',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'hana_with_coro',
#       'name': '🌺華 🌺',
#       'id': 1231206328070103040,
#       'id_str': '1231206328070103040',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389950913331154945,
#    'in_reply_to_status_id_str': '1389950913331154945',
#    'in_reply_to_user_id': 1231206328070103040,
#    'in_reply_to_user_id_str': '1231206328070103040',
#    'in_reply_to_screen_name': 'hana_with_coro',
#    'user': {'id': 1177727474739773441,
#     'id_str': '1177727474739773441',
#     'name': 'meetanyan',
#     'screen_name': 'meetanyan',
#     'location': '',
#     'description': 'さらさら ふわふわ ひらひら キラキラ いいことはたくさんある。 忘れてしまういいことを 言葉にとどめてみたくなりました',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40,
#     'friends_count': 99,
#     'listed_count': 0,
#     'created_at': 'Fri Sep 27 23:33:57 +0000 2019',
#     'favourites_count': 17854,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2293,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1177729304676880384/kJ30E8Ii_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1177729304676880384/kJ30E8Ii_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:00 +0000 2021',
#    'id': 1389952272814153728,
#    'id_str': '1389952272814153728',
#    'text': '@rILrIE 猫ってたまに一点を見詰めて動かなくなるので恐怖です😇でも今回ほど驚いた顔は無いですね…こええー🤣',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rILrIE',
#       'name': 'リーリエ',
#       'id': 1318174968761315328,
#       'id_str': '1318174968761315328',
#       'indices': [0, 7]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1389951902096396291,
#    'in_reply_to_status_id_str': '1389951902096396291',
#    'in_reply_to_user_id': 1318174968761315328,
#    'in_reply_to_user_id_str': '1318174968761315328',
#    'in_reply_to_screen_name': 'rILrIE',
#    'user': {'id': 327930906,
#     'id_str': '327930906',
#     'name': '友',
#     'screen_name': 'yukapoke',
#     'location': 'いつもｿﾅﾎﾟｹの側に、離れてたってずっと一緒(｡•з•)♡',
#     'description': 'ｿﾅｰﾎﾟｹｯﾄが大好き(*´∇`*)♥ｿﾅﾎﾟｹ常No1♥ｿﾅﾎﾟｹ常Only1♥自分の好きなもの思ったこと呟いてく(°∀°)最近のﾂｲｰﾄはｼﾞｮｼﾞｮ・ｺｽﾌﾟﾚ関連＆RT多め､通知はｵﾌにしてるので皆様の気付かなかったらごめんなさい🙏💦',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 203,
#     'friends_count': 234,
#     'listed_count': 6,
#     'created_at': 'Sat Jul 02 12:16:04 +0000 2011',
#     'favourites_count': 54274,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 43725,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000853449614/5185047c6747b30f6e949bf798897ce7_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000853449614/5185047c6747b30f6e949bf798897ce7_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/327930906/1415519863',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:00 +0000 2021',
#    'id': 1389952272776384513,
#    'id_str': '1389952272776384513',
#    'text': 'いこ猫おき猫設定。\nイコさんも隠岐君も自分語りの時は人型。みんぐ先輩視点では猫型。\n言葉は通じないけど意思の疎通はあります。\nみんぐ先輩はイコさんをイコさん、おきくんをおき、と呼んでます。\nおきくんは始めはおきくん呼びしてたけど、… https://t.co/gIYTlpxCsD',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gIYTlpxCsD',
#       'expanded_url': 'https://twitter.com/i/web/status/1389952272776384513',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1350268104803119106,
#     'id_str': '1350268104803119106',
#     'name': 'ねごみ',
#     'screen_name': 'Dd5msHFAoUzxswL',
#     'location': 'KANSAI地方',
#     'description': '成人済のぼんやりぐだぐだお絵描き修行中。超絶アナログ。せめてちゃんと絵をうｐできるようにしたい（悲）\n只今WT沼で溺れてます。主にいこおき、水隠岐、水マリ。でも全員大好きだ!!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 40,
#     'friends_count': 43,
#     'listed_count': 2,
#     'created_at': 'Sat Jan 16 02:26:58 +0000 2021',
#     'favourites_count': 4821,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1255,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1350308316883296258/VcgQUnpe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1350308316883296258/VcgQUnpe_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1350268104803119106/1610773857',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:00 +0000 2021',
#    'id': 1389952272461832192,
#    'id_str': '1389952272461832192',
#    'text': '水猫りんご🐱🍎の配信を #IRIAM で視聴中！\nhttps://t.co/XYtDoMyWiQ',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'IRIAM', 'indices': [12, 18]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/XYtDoMyWiQ',
#       'expanded_url': 'https://web.iriam.app/s/share/PHIGpP',
#       'display_url': 'web.iriam.app/s/share/PHIGpP',
#       'indices': [25, 48]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://iriam.com/" rel="nofollow">IRIAM</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1134869851879559169,
#     'id_str': '1134869851879559169',
#     'name': '詩時実(しじみ)@Vtuber準備中',
#     'screen_name': '443VS',
#     'location': '世界のどこか',
#     'description': '元、NOS・EDENです。\nYouTubeで名前が被ったのでやむを得ず改名しました！\n・Vtuber(Vsinger)準備中\n・ボカロP\n・ギター\n・ボーカル\n・ブログ\n\nアイコン作者様…あぶりカルビさん\nヘッダーイラスト作者様…花畑しおちゃん',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 516,
#     'friends_count': 873,
#     'listed_count': 9,
#     'created_at': 'Sat Jun 01 17:10:32 +0000 2019',
#     'favourites_count': 11970,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8634,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1376915607216517120/PgnGho65_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1376915607216517120/PgnGho65_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1134869851879559169/1617085412',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:37:00 +0000 2021',
#    'id': 1389952271895519244,
#    'id_str': '1389952271895519244',
#    'text': '立入禁止区域内から涼しい顔して出てきた\n\n#猫 #cat #片耳猫 #羽ちゃん https://t.co/WvQFJRlMqg',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '猫', 'indices': [21, 23]},
#      {'text': 'cat', 'indices': [24, 28]},
#      {'text': '片耳猫', 'indices': [29, 33]},
#      {'text': '羽ちゃん', 'indices': [34, 39]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1389952262194139143,
#       'id_str': '1389952262194139143',
#       'indices': [40, 63],
#       'media_url': 'http://pbs.twimg.com/media/E0oaN9rVEAcvIK7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0oaN9rVEAcvIK7.jpg',
#       'url': 'https://t.co/WvQFJRlMqg',
#       'display_url': 'pic.twitter.com/WvQFJRlMqg',
#       'expanded_url': 'https://twitter.com/tebukurotohane/status/1389952271895519244/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1389952262194139143,
#       'id_str': '1389952262194139143',
#       'indices': [40, 63],
#       'media_url': 'http://pbs.twimg.com/media/E0oaN9rVEAcvIK7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0oaN9rVEAcvIK7.jpg',
#       'url': 'https://t.co/WvQFJRlMqg',
#       'display_url': 'pic.twitter.com/WvQFJRlMqg',
#       'expanded_url': 'https://twitter.com/tebukurotohane/status/1389952271895519244/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#        'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1321383557059604481,
#     'id_str': '1321383557059604481',
#     'name': 'てぶはね',
#     'screen_name': 'tebukurotohane',
#     'location': '',
#     'description': 'てぶくろと羽の記録。\n2020年現在、てぶくろちゃん5歳，羽ちゃん0歳。共に女子。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 29,
#     'friends_count': 12,
#     'listed_count': 2,
#     'created_at': 'Wed Oct 28 09:29:54 +0000 2020',
#     'favourites_count': 170,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 599,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321383958882381825/jljgNa39_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321383958882381825/jljgNa39_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1321383557059604481/1603878579',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:59 +0000 2021',
#    'id': 1389952268418490373,
#    'id_str': '1389952268418490373',
#    'text': '@takavet1 黒猫のタンゴ🎵ですよね～☺️',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'takavet1',
#       'name': 'Takayuki Miyazawa',
#       'id': 1221587230583476226,
#       'id_str': '1221587230583476226',
#       'indices': [0, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1389897235094065153,
#    'in_reply_to_status_id_str': '1389897235094065153',
#    'in_reply_to_user_id': 1221587230583476226,
#    'in_reply_to_user_id_str': '1221587230583476226',
#    'in_reply_to_screen_name': 'takavet1',
#    'user': {'id': 4218804887,
#     'id_str': '4218804887',
#     'name': 'ランママ',
#     'screen_name': 'himejirantan',
#     'location': '',
#     'description': '出来る事ならこの世からワンちゃん🐶猫ちゃん🐱を消したい✨\nそして『殺処分・毒殺・虐殺・虐待』のない世界に連れて行ってあげたいな✨\n自然界もカラス・イタチ・キツネに襲われる事もあるけど、人間が一番残酷だよね😞',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2248,
#     'friends_count': 1673,
#     'listed_count': 22,
#     'created_at': 'Wed Nov 18 15:05:54 +0000 2015',
#     'favourites_count': 114556,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 48844,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1353207704852946945/c_Q69suu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353207704852946945/c_Q69suu_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4218804887/1611465278',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:57 +0000 2021',
#    'id': 1389952261795635200,
#    'id_str': '1389952261795635200',
#    'text': 'TLが“猫を撮るサトシ”“整体を受けるサトシ”“イタイイタイ言うてるサトシ”“食事をするだけのサトシ(?)”“寝起きのサトシ(?)”の5本立てとなっておられますのでもうサトシで酔えます(未成年)',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1033985530357137408,
#     'id_str': '1033985530357137408',
#     'name': 'マ ユ',
#     'screen_name': 'my__brothers',
#     'location': '',
#     'description': '宿命ブラバンクラパ！！！髭男チームを愛しております！！！！ #四六時中くしゃみしてますのでそこのボーカルさん早く魂留めさせて',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 77,
#     'friends_count': 70,
#     'listed_count': 3,
#     'created_at': 'Mon Aug 27 07:52:15 +0000 2018',
#     'favourites_count': 10312,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 974,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1170613855082270720/ZnekCDMm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170613855082270720/ZnekCDMm_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1033985530357137408/1592847592',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:57 +0000 2021',
#    'id': 1389952261057499138,
#    'id_str': '1389952261057499138',
#    'text': '@tekemai_omochi 猫好きさんにヒットするといいなと(笑)😻',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tekemai_omochi',
#       'name': 'もちもちおもち（てけまい）',
#       'id': 2791583150,
#       'id_str': '2791583150',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389949977690918923,
#    'in_reply_to_status_id_str': '1389949977690918923',
#    'in_reply_to_user_id': 2791583150,
#    'in_reply_to_user_id_str': '2791583150',
#    'in_reply_to_screen_name': 'tekemai_omochi',
#    'user': {'id': 1125179918,
#     'id_str': '1125179918',
#     'name': 'ﾊﾉﾚﾅ@本業休業中',
#     'screen_name': 'harumame520',
#     'location': '',
#     'description': '馬乗りカイロプラクター。カラダマニアちゃんねるアシスタント。あとは馬とか猫とか美味しいものとか。YouTube観てね✨',
#     'url': 'https://t.co/D4E4tfk5xh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/D4E4tfk5xh',
#         'expanded_url': 'https://www.youtube.com/channel/UCyZ2zrHx_8p96fJNt_VjjrA',
#         'display_url': 'youtube.com/channel/UCyZ2z…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 717,
#     'friends_count': 578,
#     'listed_count': 16,
#     'created_at': 'Sun Jan 27 14:16:08 +0000 2013',
#     'favourites_count': 14587,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 33169,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1337719748323205120/FQSxc0tN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1337719748323205120/FQSxc0tN_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1125179918/1598660061',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:54 +0000 2021',
#    'id': 1389952248902389767,
#    'id_str': '1389952248902389767',
#    'text': 'すぅ〜…はぁ〜…\n\nにゃん！にゃぁ〜ん！\nにゃぉ〜〜！にゃう！にゃん！\nにゃんにゃん！\n(恥ずかしそうに猫ポーズをして)',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1291354003591188482,
#     'id_str': '1291354003591188482',
#     'name': '藍︵良',
#     'screen_name': 'Aira_ALKALOID',
#     'location': 'トゲあるラブリー',
#     'description': '区別名 愛咲 仕様書【https://t.co/08wyDhCV6Y】 ”おれの大事な恋人ォ♡ @Mika_osisan ”',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/08wyDhCV6Y',
#         'expanded_url': 'https://profcard.info/u/qL45DIQjwQbpNz6i1QyshPECPKA3',
#         'display_url': 'profcard.info/u/qL45DIQjwQbp…',
#         'indices': [11, 34]}]}},
#     'protected': False,
#     'followers_count': 116,
#     'friends_count': 116,
#     'listed_count': 1,
#     'created_at': 'Thu Aug 06 12:42:49 +0000 2020',
#     'favourites_count': 1654,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5287,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1389925946753380355/PJe6fknO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1389925946753380355/PJe6fknO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1291354003591188482/1620020854',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:54 +0000 2021',
#    'id': 1389952248315146241,
#    'id_str': '1389952248315146241',
#    'text': 'ぬこパンで潜伏黒猫して初夜㌧するのはかなちい。\n猫又の時は全然噛まれないのに！！',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1269938671450374144,
#     'id_str': '1269938671450374144',
#     'name': 'ピカブー',
#     'screen_name': 'peekaboo1127',
#     'location': '愛知',
#     'description': '人狼J用。\n参加やや少なめ\n月曜火曜は仕事お休みです♪\nLIKE▶野球、アイドル、アニメ、食',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 147,
#     'friends_count': 147,
#     'listed_count': 2,
#     'created_at': 'Mon Jun 08 10:26:08 +0000 2020',
#     'favourites_count': 1473,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1536,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1376857482698518529/WbAMlayn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1376857482698518529/WbAMlayn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1269938671450374144/1619871299',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:54 +0000 2021',
#    'id': 1389952247669288962,
#    'id_str': '1389952247669288962',
#    'text': '猫 \n\n#Peing #質問箱 https://t.co/uiC22IktRb',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Peing', 'indices': [4, 10]},
#      {'text': '質問箱', 'indices': [11, 15]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/uiC22IktRb',
#       'expanded_url': 'https://peing.net/ja/qs/999614137',
#       'display_url': 'peing.net/ja/qs/999614137',
#       'indices': [16, 39]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://peing.net" rel="nofollow">Peing</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1132239693838372864,
#     'id_str': '1132239693838372864',
#     'name': 'ののきょん フォロバ100 🐶ラブコメ同盟会Ｎｏ．187 強垢23分達成',
#     'screen_name': 'nono___gemes',
#     'location': '……🤔',
#     'description': '独り言が多いです',
#     'url': 'https://t.co/slTCpOBhu9',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/slTCpOBhu9',
#         'expanded_url': 'https://peing.net/ja/nono___gemes',
#         'display_url': 'peing.net/ja/nono___gemes',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4922,
#     'friends_count': 3861,
#     'listed_count': 74,
#     'created_at': 'Sat May 25 10:59:13 +0000 2019',
#     'favourites_count': 34225,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 65162,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1382692092074471433/9ufvSljS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1382692092074471433/9ufvSljS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132239693838372864/1613216437',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:54 +0000 2021',
#    'id': 1389952246327115779,
#    'id_str': '1389952246327115779',
#    'text': '@haisdadhigher ぱぱさん、こんばんは( ´ ▽ ` )ﾉ今日もお疲れさまです(⊛╹〰╹⊛)ゴールデンウィークも終わってしまいますが、素敵な夢を～おやすみなさい⭐\n\n猫さんらて♬かわいい💕',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'haisdadhigher',
#       'name': '「はい」のpapa',
#       'id': 446972153,
#       'id_str': '446972153',
#       'indices': [0, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389748937028870152,
#    'in_reply_to_status_id_str': '1389748937028870152',
#    'in_reply_to_user_id': 446972153,
#    'in_reply_to_user_id_str': '446972153',
#    'in_reply_to_screen_name': 'haisdadhigher',
#    'user': {'id': 552342479,
#     'id_str': '552342479',
#     'name': '晴れ時々🐾きぃ☆(ﾟ∀ﾟゞ)',
#     'screen_name': 'guten_tag_key',
#     'location': 'お日様の下',
#     'description': '苦しい時は馬鹿になったが勝ちと思う今日このごろ(｡≖‿≖ฺ)ﾌﾟ …さぶ垢@gluck_key',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 366,
#     'friends_count': 304,
#     'listed_count': 17,
#     'created_at': 'Fri Apr 13 02:06:30 +0000 2012',
#     'favourites_count': 32303,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 264453,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/876420571298283521/MV0tBQPS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/876420571298283521/MV0tBQPS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/552342479/1396316614',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:54 +0000 2021',
#    'id': 1389952246230642694,
#    'id_str': '1389952246230642694',
#    'text': 'ガチガチの獣ってよりも人間に猫耳生えた程度が好き。つまりウマ娘はど真ん中',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1389951702502047755,
#    'in_reply_to_status_id_str': '1389951702502047755',
#    'in_reply_to_user_id': 1208664114773426177,
#    'in_reply_to_user_id_str': '1208664114773426177',
#    'in_reply_to_screen_name': 'RAMUNERUNERUME',
#    'user': {'id': 1208664114773426177,
#     'id_str': '1208664114773426177',
#     'name': '😈ラムネ😈',
#     'screen_name': 'RAMUNERUNERUME',
#     'location': '布団の中',
#     'description': 'あんまり呟きません\n生き別れの妹がいたら嬉しかったです\n美人なお姉さんに拾われたかったです',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16,
#     'friends_count': 155,
#     'listed_count': 0,
#     'created_at': 'Sun Dec 22 08:22:59 +0000 2019',
#     'favourites_count': 7176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 600,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321472427226918912/HmEj7R-J_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321472427226918912/HmEj7R-J_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1208664114773426177/1612435040',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:36:53 +0000 2021',
#    'id': 1389952244200574977,
#    'id_str': '1389952244200574977',
#    'text': '最高に気持ち悪くて同じ部活なのうざすぎて爆発しそう。部活の時も猫かぶって声めちゃくちゃデカくてうるさいしぶりっ子してるのよねきっしょいなぁ',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1355899403714748421,
#     'id_str': '1355899403714748421',
#     'name': 'ﾀﾞ',
#     'screen_name': 'MoTegYVlqZ5Eaog',
#     'location': '',
#     'description': 'つぶやくだけ 愚痴多め 愚痴共有したい人ぜひ',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5,
#     'friends_count': 76,
#     'listed_count': 0,
#     'created_at': 'Sun Jan 31 15:23:20 +0000 2021',
#     'favourites_count': 48,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 188,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1355904700097286145/3BQ-FaoE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1355904700097286145/3BQ-FaoE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1355899403714748421/1612107847',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
# ...
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 118,
#     'friends_count': 198,
#     'listed_count': 13,
#     'created_at': 'Sat Feb 03 07:13:47 +0000 2018',
#     'favourites_count': 5425,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7018,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1388871387469684745/7XAs6F_M_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1388871387469684745/7XAs6F_M_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/959686337036140544/1619624815',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:35:58 +0000 2021',
#    'id': 1389952012297461765,
#    'id_str': '1389952012297461765',
#    'text': 'で、お互いに双方の神様に乗り移られてお膳立てされるんだけど実は犬神様と猫神様が不仲で影響されて喧嘩になりどんどん神様に引きづられてケモ耳とか生えてきちゃう。神様も願いは叶えなきゃだからそのまま力技でセッに持ち込むけど、急に神様が離脱して意識を取り戻した杉尾はセッ真っ最中…なやつ！',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389951103245029383,
#    'in_reply_to_status_id_str': '1389951103245029383',
#    'in_reply_to_user_id': 164395602,
#    'in_reply_to_user_id_str': '164395602',
#    'in_reply_to_screen_name': 'tabakomushi',
#    'user': {'id': 164395602,
#     'id_str': '164395602',
#     'name': 'たばこ虫',
#     'screen_name': 'tabakomushi',
#     'location': '基本的にひとり上手',
#     'description': '金カム沼落ちたて成人出戻りの尾モンペ/杉尾が8割/宇佐尾/勇尾/尾右固定/本誌呟きます/ほとんど妄想の話/R18/殺し合う男達のクソデカ感情を捏ねるのが好きです/歴代好き→/マルジャン/ルチパウ/ジョルミス/',
#     'url': 'https://t.co/jUItotewV2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/jUItotewV2',
#         'expanded_url': 'http://www.pixiv.net/member.php?id=1378612',
#         'display_url': 'pixiv.net/member.php?id=…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 203,
#     'friends_count': 170,
#     'listed_count': 7,
#     'created_at': 'Thu Jul 08 19:40:24 +0000 2010',
#     'favourites_count': 3102,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12001,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1370305612953780229/bo4oX1HJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1370305612953780229/bo4oX1HJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/164395602/1617992789',
#     'profile_link_color': '00FFD5',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '080708',
#     'profile_text_color': '878387',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:35:58 +0000 2021',
#    'id': 1389952010733064197,
#    'id_str': '1389952010733064197',
#    'text': '@soyokazenoaits そよ風さんこんばんは🐙\n以前BOOTHでの500人企画で問い合わせをした際すぐにご連絡下さったにも関わらず、返信出来ておらず申しわけございませんでした\U0001f972\U0001f972\nいつも本当にかわいい作品ばかりで感動ばかり… https://t.co/vIpWmQTMfA',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'soyokazenoaits',
#       'name': 'そよ風のあいつ🐙',
#       'id': 1247157959433437198,
#       'id_str': '1247157959433437198',
#       'indices': [0, 15]}],
#     'urls': [{'url': 'https://t.co/vIpWmQTMfA',
#       'expanded_url': 'https://twitter.com/i/web/status/1389952010733064197',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1389117327237476355,
#    'in_reply_to_status_id_str': '1389117327237476355',
#    'in_reply_to_user_id': 1247157959433437198,
#    'in_reply_to_user_id_str': '1247157959433437198',
#    'in_reply_to_screen_name': 'soyokazenoaits',
#    'user': {'id': 1136827581855019008,
#     'id_str': '1136827581855019008',
#     'name': 'みなみ👮\u200d♂️',
#     'screen_name': 'v__vmyy',
#     'location': 'かんさい',
#     'description': '𝕸𝖆𝖑𝖑𝖊𝖚𝖘 𝕯𝖗𝖆𝖈𝖔𝖓𝖎𝖆 ....🐉💚20↑新米ぬいママ🤱 # まれぬいのいる生活 👶🍼',
#     'url': 'https://t.co/PuQ107OIeU',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PuQ107OIeU',
#         'expanded_url': 'https://twisted-wonderland.aniplex.co.jp/character/malleus',
#         'display_url': 'twisted-wonderland.aniplex.co.jp/character/mall…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 39,
#     'friends_count': 78,
#     'listed_count': 1,
#     'created_at': 'Fri Jun 07 02:49:51 +0000 2019',
#     'favourites_count': 1454,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1096,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1379478301807284227/RUPHWNdT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1379478301807284227/RUPHWNdT_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1136827581855019008/1617289677',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:35:57 +0000 2021',
#    'id': 1389952007973138434,
#    'id_str': '1389952007973138434',
#    'text': 'お布団入る前にトイレ行ったのにもうトイレに行きたいんだけど、愛猫が足に寄りかかって寝てるから動けない',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2375353304,
#     'id_str': '2375353304',
#     'name': 'すゞ茶(🌾)',
#     'screen_name': 'sleepy_sleep_y',
#     'location': '',
#     'description': '🔔｢すゞ｣と書いて｢すず｣と読みます🔔                   ⚠️基本うるさいのでミュート推奨⚠️',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1713,
#     'friends_count': 1136,
#     'listed_count': 26,
#     'created_at': 'Thu Mar 06 13:17:37 +0000 2014',
#     'favourites_count': 169293,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 63907,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/805404687578996736/5CxhsXRb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/805404687578996736/5CxhsXRb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2375353304/1612438206',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Wed May 05 14:35:56 +0000 2021',
#    'id': 1389952005133651971,
#    'id_str': '1389952005133651971',
#    'text': '1枚目の方が強いかな⁇\n白猫双剣と鈍器猫\n鈍器猫に達人芸付ける意味あり？\n\n#モンハンライズフレンド募集 https://t.co/HzOFs7zFxn',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'モンハンライズフレンド募集', 'indices': [38, 52]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1389952001312657412,
#       'id_str': '1389952001312657412',
#       'indices': [53, 76],
#       'media_url': 'http://pbs.twimg.com/media/E0oZ-x0VkAQZ6IF.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0oZ-x0VkAQZ6IF.jpg',
#       'url': 'https://t.co/HzOFs7zFxn',
#       'display_url': 'pic.twitter.com/HzOFs7zFxn',
#       'expanded_url': 'https://twitter.com/ta_ikita/status/1389952005133651971/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1389952001312657412,
#       'id_str': '1389952001312657412',
#       'indices': [53, 76],
#       'media_url': 'http://pbs.twimg.com/media/E0oZ-x0VkAQZ6IF.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0oZ-x0VkAQZ6IF.jpg',
#       'url': 'https://t.co/HzOFs7zFxn',
#       'display_url': 'pic.twitter.com/HzOFs7zFxn',
#       'expanded_url': 'https://twitter.com/ta_ikita/status/1389952005133651971/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}}},
#      {'id': 1389952001371381770,
#       'id_str': '1389952001371381770',
#       'indices': [53, 76],
#       'media_url': 'http://pbs.twimg.com/media/E0oZ-yCVoAoyhoj.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E0oZ-yCVoAoyhoj.jpg',
#       'url': 'https://t.co/HzOFs7zFxn',
#       'display_url': 'pic.twitter.com/HzOFs7zFxn',
#       'expanded_url': 'https://twitter.com/ta_ikita/status/1389952005133651971/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4845185113,
#     'id_str': '4845185113',
#     'name': '初心者の極み乙女',
#     'screen_name': 'ta_ikita',
#     'location': '浜松',
#     'description': 'バレー/バトミントン/介護/ 西野カナ/モンスト /栄冠ナイン/MHW 👑ランク600/覇者の塔、玉楼制覇！ 運極🍀500 /ガチャ限:100体以上m(._.)m 無言フォローすみません… フォロバ率100%です(*´꒳`*) マルチしたり絡んだりしていただくと喜びます🐷',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1690,
#     'friends_count': 2475,
#     'listed_count': 7,
#     'created_at': 'Mon Feb 01 15:31:25 +0000 2016',
#     'favourites_count': 84717,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2226,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/881053875683315713/OHykLvIJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/881053875683315713/OHykLvIJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4845185113/1618334843',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.106,
#   'max_id': 1389952281940877314,
#   'max_id_str': '1389952281940877314',
#   'next_results': '?max_id=1389952005133651970&q=%E7%8C%AB%20since%3A2015-07-19%20exclude%3Aretweets&lang=ja&count=100&include_entities=1&result_type=recent',
#   'query': '%E7%8C%AB+since%3A2015-07-19+exclude%3Aretweets',
#   'refresh_url': '?since_id=1389952281940877314&q=%E7%8C%AB%20since%3A2015-07-19%20exclude%3Aretweets&lang=ja&result_type=recent&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
len(list_p)
# Out:
# 0

# %%
for date in date_list[172:]:
    search = search_tweet_date(search_word, search_count, date, twitter)
    df_search = DataFrame.from_dict(search['statuses'])
    tweets = df_search['text'].tolist()
    tweets = normalize_tweets(tweets)
    wakachi = get_wakachi(tweets, search_word)
    words_list = wakachi.split(' ')
    p, n, e = getPN(words_list)
    list_p.append(p)
    list_n.append(n)
    list_e.append(e)
# Out:
# Error code: 429
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-fd154f13f9b7> in <module>
#       1 for date in date_list[172:]:
#       2     search = search_tweet_date(search_word, search_count, date, twitter)
# ----> 3     df_search = DataFrame.from_dict(search['statuses'])
#       4     tweets = df_search['text'].tolist()
#       5     tweets = normalize_tweets(tweets)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
len(list_p)
# Out:
# 349

# %%
for date in date_list[349:]:
    search = search_tweet_date(search_word, search_count, date, twitter)
    df_search = DataFrame.from_dict(search['statuses'])
    tweets = df_search['text'].tolist()
    tweets = normalize_tweets(tweets)
    wakachi = get_wakachi(tweets, search_word)
    words_list = wakachi.split(' ')
    p, n, e = getPN(words_list)
    list_p.append(p)
    list_n.append(n)
    list_e.append(e)

# %%
len(list_p)
# Out:
# 365

# %%
df_pn = DataFrame({'p':list_p, 'n':list_n, 'e':list_e}, index=date_list)
df_pn['p/n'] = (df_pn['p'] - df_pn['n'])/(df_pn['p'] + df_pn['n'])
df_pn
# Out:
#              p  n    e       p/n
# 2021-05-05  22  6  153  0.571429
# 2021-05-06  20  5  125  0.600000
# 2021-05-07  20  5  125  0.600000
# 2021-05-08  20  5  125  0.600000
# 2021-05-09  20  5  125  0.600000
# ...         .. ..  ...       ...
# 2022-04-30  22  7  158  0.517241
# 2022-05-01  22  7  158  0.517241
# 2022-05-02  22  7  158  0.517241
# 2022-05-03  22  7  158  0.517241
# 2022-05-04  22  7  158  0.517241
#
# [365 rows x 4 columns]

# %%
list_e
# Out:
# [153,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  125,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  126,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  107,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  102,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  124,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158]
